# %%
import pandas as pd
import spacy
from spacy.pipeline import EntityRuler 
from spacy.lang.en import English
from spacy import displacy

data = pd.read_csv("terms_cleaned.csv", sep=",")[['pattern', 'pilot']]
data = data.drop_duplicates()

# %%
new_data = pd.DataFrame(
    {"pattern" : [], "pilot" : []}
)
data.pattern.unique()
# Out:
# array(['N', 'N N', 'A N', 'A N N', 'N N N', 'A C A N', 'A N P N',
#        'N C N P N', 'A A N', 'A', 'A N N N', 'N P N', 'N P A N',
#        'N P N N', 'R', 'N A N', 'N C N N', 'A A N N', 'N V A', 'A N A N',
#        'N C A N', 'N N N N', 'A N P N N', 'N N P N', 'N P N P N',
#        'A A A N', 'R A N', 'A C A N N'], dtype=object)

# %%
#data[data['pattern'] == 'A C A N']

# %% [markdown]
# # ACAN to AN

# %%
ACAN_rows = data[data['pattern'] == 'A C A N']
for index, row in ACAN_rows.iterrows():
    first_elt = " ".join([row['pilot'].split(" ")[0],row['pilot'].split(" ")[3]])
    second_elt = " ".join(row['pilot'].split(" ")[-2:])
    new_data = new_data.append({'pattern': 'A N', 'pilot' : first_elt}, ignore_index=True)
    new_data = new_data.append({'pattern': 'A N', 'pilot' : second_elt}, ignore_index=True)

data = data.append(new_data, ignore_index=True).drop_duplicates()
data
# Out:
#      pattern                             pilot
# 0          N                       annotations
# 1        N N               emotion recognition
# 2        A N             emotional recognition
# 3      A N N  speech-based emotion recognition
# 4      A N N     automated emotion recognition
# ...      ...                               ...
# 1716     A N                   implicit manner
# 1717     A N                    dull responses
# 1718     A N                 generic responses
# 1719     A N                     mental health
# 1720     A N                   physical health
#
# [1717 rows x 2 columns]

# %% [markdown]
# # Lemmatization

# %%
from spacy.lemmatizer import Lemmatizer, ADJ, NOUN, VERB 
nlp = spacy.load('en')

lemmatizer = nlp.vocab.morphology.lemmatizer

lemmas = []
for index ,row in data.iterrows():
    lemmas.append((lemmatizer(row['pilot'], NOUN)[0], row['pattern']))

lemmas_df = pd.DataFrame(
    {"pattern" : [lemma[1] for lemma in lemmas], "pilot" : [lemma[0] for lemma in lemmas]}
)
lemmas_df
data = data.append(lemmas_df, ignore_index=True).drop_duplicates()
data
# Out:
#       pattern                             pilot
# 0           N                       annotations
# 1         N N               emotion recognition
# 2         A N             emotional recognition
# 3       A N N  speech-based emotion recognition
# 4       A N N     automated emotion recognition
# ...       ...                               ...
# 3415  N P N N            range of story progres
# 3426      A N                      male emotion
# 3427      A N                    female emotion
# 3430      A N                     dull response
# 3431      A N                  generic response
#
# [2203 rows x 2 columns]

# %% [markdown]
# # Find plural of terms

# %%
import inflect
engine = inflect.engine()
plural = engine.plural("male emotion")
plural
# Out:
# 'male emotions'

# %%
plurals = []
for index ,row in data.iterrows():
    plurals.append((engine.plural(row['pilot']), row['pattern']))

plurals_df = pd.DataFrame(
    {"pattern" : [plural[1] for plural in plurals], "pilot" : [plural[0] for plural in plurals]}
)
data = data.append(plurals_df, ignore_index=True).drop_duplicates()
#data

# %%
#save as csv
data.to_csv('terms.csv', index=False)

# %% [markdown]
# ## rule-based system

# %%
patterns = []
for index, row in data.iterrows():
    patterns.append(
        {"label" : "NLP term", "pattern" : row["pilot"]}
    )
nlp = English()
ruler = EntityRuler(nlp)
ruler.add_patterns(patterns)
nlp.add_pipe(ruler)

# %% [markdown]
# #### some exemple

# %%
doc = nlp("The corpus is a data set, an annotator is given")

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# corpus 4 10 NLP term
# data set 16 24 NLP term
# annotator 29 38 NLP term

# %%
displacy.render(doc, style="ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corpus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data set
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# , an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     annotator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is given</div></span>

# %% [markdown]
# # neural network approach

# %% [markdown]
# ### extract text from train articles

# %%
import os
Sentences = []
for filename in os.listdir('main18/'):
    text = open('main18/'+filename, 'r')
    sentences = text.read().split(".")
    Sentences += sentences

Sentences = [sentence.replace('\n', ' ') for sentence in Sentences ]

# %%
TRAIN_DATA=[]
for sentence in Sentences:
    doc = nlp(sentence)
    TRAIN_DATA.append(['',{'entities' : []}])
    for ent in doc.ents:
        TRAIN_DATA[-1][1]['entities'].append((ent.start_char, ent.end_char, ent.label_))
    TRAIN_DATA[-1] = (sentence, TRAIN_DATA[-1][1])

i = 0
while i<len(TRAIN_DATA):
    if TRAIN_DATA[i][0] == '' or len(TRAIN_DATA[i][1]['entities']) == 0:
        TRAIN_DATA.pop(i)
    else:
        i += 1

# %%
import spacy
import random
from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from sklearn.metrics import accuracy_score

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')  # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
# add labels
    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])
# get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes):  # only train NER
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  # batch of texts
                    [annotations],  # batch of annotations
                    drop=0.2,  # dropout - make it harder to memorise data
                    sgd=optimizer,  # callable to update weights
                    losses=losses)
            print(losses)
    return nlp
prdnlp = train_spacy(TRAIN_DATA, 40)
# Out:
# /Users/macbookpro/TAL_projects/.essay_grading_system_env/lib/python3.7/site-packages/spacy/language.py:639: UserWarning: [W033] Training a new parser or NER using a model with no lexeme normalization table. This may degrade the performance of the model to some degree. If this is intentional or the language you're using doesn't have a normalization table, please ignore this warning. If this is surprising, make sure you have the spacy-lookups-data package installed. The languages with lexeme normalization tables are currently: da, de, el, en, id, lb, pt, ru, sr, ta, th.
#   **kwargs
# Statring iteration 0
# {'ner': 11116.020741332337}
# Statring iteration 1
# {'ner': 7772.422429557916}
# Statring iteration 2
# {'ner': 6894.399181174071}
# Statring iteration 3
# {'ner': 5987.574831980829}
# Statring iteration 4
# {'ner': 5483.9327484651585}
# Statring iteration 5
# {'ner': 5040.783829466195}
# Statring iteration 6
# {'ner': 4629.612497414617}
# Statring iteration 7
# {'ner': 4332.434756173612}
# Statring iteration 8
# {'ner': 4008.6702479204596}
# Statring iteration 9
# {'ner': 3828.6495593355817}
# Statring iteration 10
# {'ner': 3601.5171727655297}
# Statring iteration 11
# {'ner': 3164.35928676709}
# Statring iteration 12
# {'ner': 3225.916890523705}
# Statring iteration 13
# {'ner': 3037.053566150275}
# Statring iteration 14
# {'ner': 2745.627204562233}
# Statring iteration 15
# {'ner': 2758.500604944274}
# Statring iteration 16
# {'ner': 2583.354730319179}
# Statring iteration 17
# {'ner': 2463.4011183202724}
# Statring iteration 18
# {'ner': 2254.3209167610135}
# Statring iteration 19
# {'ner': 2089.409261751411}
# Statring iteration 20
# {'ner': 2036.5245658708309}
# Statring iteration 21
# {'ner': 2109.889046337308}
# Statring iteration 22
# {'ner': 1782.5138591332043}
# Statring iteration 23
# {'ner': 1789.5156702737063}
# Statring iteration 24
# {'ner': 1776.5460721843915}
# Statring iteration 25
# {'ner': 1647.427525365428}
# Statring iteration 26
# {'ner': 1610.229784762433}
# Statring iteration 27
# {'ner': 1614.7818602286688}
# Statring iteration 28
# {'ner': 1533.9961399452266}
# Statring iteration 29
# {'ner': 1349.4808297188017}
# Statring iteration 30
# {'ner': 1424.932227668526}
# Statring iteration 31
# {'ner': 1478.2324961857498}
# Statring iteration 32
# {'ner': 1453.479217686312}
# Statring iteration 33
# {'ner': 1395.4298417348857}
# Statring iteration 34
# {'ner': 1253.596675683641}
# Statring iteration 35
# {'ner': 1338.348098723435}
# Statring iteration 36
# {'ner': 1236.676311479801}
# Statring iteration 37
# {'ner': 1234.923244113848}
# Statring iteration 38
# {'ner': 1153.334427290966}
# Statring iteration 39
# {'ner': 1224.8579578670879}

# %%
# Save our trained Model
modelfile = "neural network annotator"
prdnlp.to_disk(modelfile)

# %% [markdown]
# # Testing the two systems

# %% [markdown]
# ### Loading test articles

# %%
import os
import re

articles = []
for filename in os.listdir('test2/'):
    text = open('test2/'+filename, 'r')
    articles.append(text.read().replace('\n', ' '))
    text.close()
articles = " ".join(articles)
articles = re.sub(' +', ' ', articles) 

#true results

test_true = pd.read_csv("test_cleaned.tsv", sep="\t")[['pilot','freq']]
test_true
# Out:
# ['RAVDESS',
#  'Enc-bef',
#  'corpus',
#  'speech recognition',
#  'automatic speech recognition',
#  'Enc-aft',
#  'CREMA-D',
#  'datasets',
#  'decoder',
#  'emotional speech',
#  'manual transcripts',
#  'encoder',
#  'Speaker Identity',
#  'thankfulness',
#  'Seq2Seq models',
#  'LSTM',
#  'MSP-IMPROV Target',
#  'MSP-IMPROV Target RAVDESS',
#  'Actor Identity',
#  'speech recognition performance',
#  'Confusion matrix of model',
#  'dialogue generation',
#  'Automatic Dialogue Generation',
#  'conversational agent',
#  'Seq2Seq',
#  'dataset',
#  'statistical significance',
#  'Statistical Significance of Emotion',
#  'dialogue models',
#  'emotion classifier',
#  'emotion mining classifier',
#  'neutral speech',
#  'target utterances',
#  'vector',
#  'APIs',
#  'automatic speech recognition',
#  'emotion mining',
#  'emotion mining classifier',
#  'recognition accuracy',
#  'lexical content',
#  'recognition systems',
#  'Word Error Rate',
#  '1-CR',
#  'emotion mining classifier',
#  'trainable',
#  'emotional content',
#  'RAVDESS and MSP-IMPROV Target',
#  'ASR system',
#  'WERs',
#  'sequence of words',
#  'ASR performance',
#  'impact of Emotion',
#  'target sentence',
#  'specific emotion',
#  'performance of commercial systems',
#  'cross-comparison',
#  'cross-comparison WER',
#  'Emotional intelligence',
#  'emotion is identical',
#  'hidden state',
#  'Spearman Correlation',
#  'complete conversations',
#  'relative performance',
#  'source utterance',
#  'matrix of model Enc-aft',
#  'ANOVA analysis',
#  'neural dialogue generation systems',
#  'source target',
#  'previous utterance',
#  'speech recognition systems',
#  'language model',
#  'Statistical Significance of Emotion',
#  'response generation',
#  'FastText',
#  'MSP-IMPROV Target RAVDESS',
#  'emotion tagger',
#  'P-value',
#  'Automatic Dialogue Generation',
#  'machine translation',
#  'interlocutor',
#  'observed WER',
#  'source sentences',
#  'F-value',
#  'transcription',
#  'average accuracies',
#  'generative models',
#  'mapping rules',
#  'highest impact',
#  'natural speech',
#  'Dec model',
#  'emotion vector',
#  'input message-response pairs',
#  'model Enc-bef',
#  'dialogue corpora',
#  'nonimprovised speech',
#  'F1-score',
#  'template-based',
#  'spoken-content',
#  'non-improvised',
#  'LSTMs',
#  'Adam optimizer',
#  'grammatically',
#  'diagonals',
#  'maximum-likelihood estimation',
#  'NonEmotion',
#  'Non-emotion',
#  'empirically',
#  'F-values',
#  'size of the vocabulary space',
#  'coder',
#  'MFCCs',
#  'minimal length',
#  'formant frequencies',
#  'Mel-frequency cepstral coefficients',
#  'non-committal',
#  'dialog structure',
#  'Goldwater',
#  'data-driven',
#  'subset',
#  'impactful',
#  'HAPINESS',
#  'true WER',
#  'MSPIMPROV',
#  'MFCC',
#  'overfitting',
#  'Sequence-tosequence',
#  'major components',
#  'concatenation',
#  'state-based',
#  'utterances',
#  'metric',
#  'emotion',
#  'Correlation',
#  'semantic',
#  'approximation',
#  'NEUTRAL',
#  'sadness',
#  'evaluation',
#  'disgust',
#  'accuracies',
#  'generic',
#  'dialogue',
#  'model',
#  'interactions',
#  'manually',
#  'token',
#  'specific',
#  'randomly',
#  'guilt',
#  'input',
#  'ambiguous',
#  'speech',
#  'anger',
#  'emotionally',
#  'content',
#  'learning',
#  'natural',
#  'Pearson',
#  'side effect',
#  'coherent',
#  'parameters',
#  'speaker',
#  'precision',
#  'loneliness',
#  'variation',
#  'response',
#  'intensities',
#  'sentences',
#  'HAPPINESS',
#  'experiments',
#  'data',
#  'conversations',
#  'afraid',
#  'surprise',
#  'layer',
#  'method',
#  'fear',
#  'generation',
#  'samples',
#  'compassion',
#  'dull',
#  'love',
#  'source',
#  'intense',
#  'output',
#  'systems',
#  'recordings',
#  'dark',
#  'framework',
#  'style',
#  'Happy',
#  'display',
#  'versions',
#  'confidence',
#  'agreement']

# %% [markdown]
# ### Rule-based system

# %%
import collections

doc = nlp(articles.lower())
entities = []
for ent in doc.ents:
    #print(ent.text, ent.start_char, ent.end_char, ent.label_)
    entities.append(ent.text)

RB_results = collections.Counter(entities)
#results
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  impacts
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speech recognition
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  performance abstract it has been established that the performance of speech
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recognition systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  depends on multiple
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     factors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  including the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lexical content
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speaker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  identity and dialect. here we use three english
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     datasets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  of acted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  to demonstrate that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotional content
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  also impacts the performance of commercial systems. on two of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corpora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is a bigger contributor to recognition errors than
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speaker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  identity and on two,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neutral speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is recognized considerably better than
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotional speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# . we further evaluate the commercial systems on spontaneous interactions that contain portions of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotional speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# . we propose and validate on the acted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     datasets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# , a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     method
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  that allows us to evaluate the overall impact of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  on recognition even when
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  transcripts are not available. using this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     method
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# , we show that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  in natural spontaneous
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dialogue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius:

# %% [markdown]
# ### Supervised trained model system

# %%
import spacy
import os

prdnlp = spacy.load("neural network annotator") # 
doc = prdnlp(articles.lower())
entities = []
for ent in doc.ents:
    #print(ent.text, ent.start_char, ent.end_char, ent.label_)
    entities.append(ent.text)

NN_results = collections.Counter(entities)
#displacy.render(doc, style="ent", jupyter = True)
NN_results['dialogue']

displacy.render(doc, style="ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  impacts
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speech recognition performance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  abstract it has been established that the performance of speech
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recognition systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  depends on multiple
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     factors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  including the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lexical content
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speaker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  identity and dialect. here we use three english
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     datasets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  of acted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  to demonstrate that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotional content
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  also impacts the performance of commercial systems. on two of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corpora
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is a bigger contributor to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     recognition errors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  than
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speaker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  identity and on two,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     neutral speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  is recognized considerably better than
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotional speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# . we further evaluate the commercial systems on spontaneous interactions that contain
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     portions of emotional speech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# . we propose and validate on the acted
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     datasets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# , a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     method
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  that allows us to evaluate the overall impact of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  on recognition even when
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     manual
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
#  transcripts are not available. using this
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     method
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NLP term</span>
# </mark>
# , we show that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     emotion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercas

# %% [markdown]
# #### Showing some differences on the results given by the two systems

# %%
import plotly.graph_objects as go
import random

terms = [random.choice(list(test_true.pilot.values)) for i in range(14)]
terms.append('dialogue')
fig = go.Figure(data=[
    go.Bar(name='Rule-based model', x=terms, y=[RB_results[term] for term in terms]),
    go.Bar(name='Supervised model', x=terms, y=[NN_results[term] for term in terms]),

])

fig.update_layout(barmode='group')
fig.show()
# Out:
# <div>                            <div id="a601347f-b3b9-42d9-8a66-88e38d105e0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a601347f-b3b9-42d9-8a66-88e38d105e0f")) {                    Plotly.newPlot(                        "a601347f-b3b9-42d9-8a66-88e38d105e0f",                        [{"name": "Rule-based model", "type": "bar", "x": ["versions", "speech recognition", "dark", "emotional content", "Sequence-tosequence", "specific emotion", "side effect", "emotion is identical", "MSP-IMPROV Target RAVDESS", "major components", "samples", "grammatically", "evaluation", "complete conversations", "dialogue"], "y": [0, 7, 0, 3, 0, 2, 0, 0, 0, 0, 3, 0, 6, 0, 15]}, {"name": "Supervised model", "type": "bar", "x": ["versions", "speech recognition", "dark", "emotional content", "Sequence-tosequence", "specific emotion", "side effect", "emotion is identical", "MSP-IMPROV Target RAVDESS", "major components", "samples", "grammatically", "evaluation", "complete conversations", "dialogue"], "y": [0, 3, 0, 3, 0, 2, 0, 0, 0, 1, 3, 0, 6, 0, 7]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd ...

# %%
data[data['pilot'] == "components"]
# Out:
#      pattern       pilot
# 3121       N  components

# %% [markdown]
# # Noise

# %%
# number of terms found by the neural network model and that are not correct terms
nn_noise = [term in list(test_true.pilot.values) for term in NN_results.keys()]
nn_noise = len([v for v in nn_noise if v is True])
nn_noise
# Out:
# 75

# %%
# number of terms found by the rule based model and that are not correct terms

rb_noise = [term in list(test_true.pilot.values) for term in RB_results.keys()]
rb_noise = len([v for v in rb_noise if v is True])
rb_noise
# Out:
# 65
